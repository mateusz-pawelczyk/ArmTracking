# %%
import shutil
import os

# %%
recordings_path = "Mathew"

# %%
non_csv = [x for x in os.listdir(recordings_path) if not x.endswith(".csv")]
non_csv
# Out:
# ['Mathew48.x2d',
#  'Mathew.Session 1.enf',
#  'Mathew75.xcp',
#  'Mathew90.system',
#  'Mathew37.Trial37.enf',
#  'Mathew64.c3d',
#  'Mathew23.system',
#  'Mathew12.x2d',
#  'Mathew15.Trial15.enf',
#  'Mathew43.Trial43.enf',
#  'Mathew17.system',
#  'Mathew20.Trial20.enf',
#  'Mathew99.xcp',
#  'Mathew81.system',
#  'Mathew94.x2d',
#  'Mathew68.xcp',
#  'Mathew31.system',
#  'Mathew53.system',
#  'Mathew43.system',
#  'Mathew73.xcp',
#  'Mathew47.x2d',
#  'Mathew84.x2d',
#  'Mathew81.xcp',
#  'Mathew06.xcp',
#  'Mathew95.xcp',
#  'Mathew44.x2d',
#  'Mathew82.c3d',
#  'Mathew75.Trial75.enf',
#  'Mathew24.system',
#  'Mathew71.Trial71.enf',
#  'Mathew50.x2d',
#  'Mathew58.Trial58.enf',
#  'Mathew01.system',
#  'Mathew38.system',
#  'Mathew77.Trial77.enf',
#  'Mathew16.xcp',
#  'Mathew45.Trial45.enf',
#  'Mathew16.c3d',
#  'Mathew64.system',
#  'Mathew21.c3d',
#  'Mathew90.xcp',
#  'Mathew14.system',
#  'Mathew20.x2d',
#  'Mathew63.xcp',
#  'Mathew18.system',
#  'Mathew49.c3d',
# ...

# %%
for file in non_csv:
    os.remove(os.path.join(recordings_path, file))
